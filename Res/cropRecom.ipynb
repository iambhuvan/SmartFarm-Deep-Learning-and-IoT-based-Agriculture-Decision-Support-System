# %%
import pandas as pd

# Normalizing
from sklearn.preprocessing import StandardScaler,LabelEncoder

# cross validation
from sklearn.model_selection import train_test_split

# Recommendation Algorithms
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import PassiveAggressiveClassifier

# Yield Prediction Algorithms
from sklearn.svm import LinearSVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import PassiveAggressiveRegressor

# Evaluation
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,mean_absolute_error,mean_squared_error,r2_score
# import systemcheck
import warnings
warnings.simplefilter("ignore")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import pandas as pd
#       3 # Normalizing
#       4 from sklearn.preprocessing import StandardScaler,LabelEncoder
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\__init__.py:166
#     147 from pandas.core.computation.api import eval
#     149 from pandas.core.reshape.api import (
#     150     concat,
#     151     lreshape,
#    (...)
#     163     qcut,
#     164 )
# --> 166 from pandas import api, arrays, errors, io, plotting, tseries
#     167 from pandas import testing
#     168 from pandas.util._print_versions import show_versions
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\api\__init__.py:2
#       1 """ public toolkit API """
# ----> 2 from pandas.api import (
#       3     extensions,
#       4     indexers,
#       5     interchange,
#       6     types,
#       7     typing,
#       8 )
#      10 __all__ = [
#      11     "interchange",
#      12     "extensions",
#    (...)
#      15     "typing",
#      16 ]
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\api\typing\__init__.py:31
#      19 from pandas.core.window import (
#      20     Expanding,
#      21     ExpandingGroupby,
#    (...)
#      26     Window,
#      27 )
#      29 # TODO: Can't import Styler without importing jinja2
#      30 # from pandas.io.formats.style import Styler
# ---> 31 from pandas.io.json._json import JsonReader
#      32 from pandas.io.stata import StataReader
#      34 __all__ = [
#      35     "DataFrameGroupBy",
#      36     "DatetimeIndexResamplerGroupby",
#    (...)
#      54     "Window",
#      55 ]
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\__init__.py:1
# ----> 1 from pandas.io.json._json import (
#       2     read_json,
#       3     to_json,
#       4     ujson_dumps,
#       5     ujson_loads,
#       6 )
#       7 from pandas.io.json._table_schema import build_table_schema
#       9 __all__ = [
#      10     "ujson_dumps",
#      11     "ujson_loads",
#    (...)
#      14     "build_table_schema",
#      15 ]
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\_json.py:71
#      66 from pandas.io.json._normalize import convert_to_line_delimits
#      67 from pandas.io.json._table_schema import (
#      68     build_table_schema,
#      69     parse_table_schema,
#      70 )
# ---> 71 from pandas.io.parsers.readers import validate_integer
#      73 if TYPE_CHECKING:
#      74     from collections.abc import (
#      75         Hashable,
#      76         Mapping,
#      77     )
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\__init__.py:1
# ----> 1 from pandas.io.parsers.readers import (
#       2     TextFileReader,
#       3     TextParser,
#       4     read_csv,
#       5     read_fwf,
#       6     read_table,
#       7 )
#       9 __all__ = ["TextFileReader", "TextParser", "read_csv", "read_fwf", "read_table"]
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:32
#      29 from pandas._config import using_copy_on_write
#      31 from pandas._libs import lib
# ---> 32 from pandas._libs.parsers import STR_NA_VALUES
#      33 from pandas.errors import (
#      34     AbstractMethodError,
#      35     ParserWarning,
#      36 )
#      37 from pandas.util._decorators import Appender
#
# File parsers.pyx:1418, in init pandas._libs.parsers()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import pandas as pd
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\__init__.py:166
#     147 from pandas.core.computation.api import eval
#     149 from pandas.core.reshape.api import (
#     150     concat,
#     151     lreshape,
#    (...)
#     163     qcut,
#     164 )
# --> 166 from pandas import api, arrays, errors, io, plotting, tseries
#     167 from pandas import testing
#     168 from pandas.util._print_versions import show_versions
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\api\__init__.py:2
#       1 """ public toolkit API """
# ----> 2 from pandas.api import (
#       3     extensions,
#       4     indexers,
#       5     interchange,
#       6     types,
#       7     typing,
#       8 )
#      10 __all__ = [
#      11     "interchange",
#      12     "extensions",
#    (...)
#      15     "typing",
#      16 ]
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\api\typing\__init__.py:31
#      19 from pandas.core.window import (
#      20     Expanding,
#      21     ExpandingGroupby,
#    (...)
#      26     Window,
#      27 )
#      29 # TODO: Can't import Styler without importing jinja2
#      30 # from pandas.io.formats.style import Styler
# ---> 31 from pandas.io.json._json import JsonReader
#      32 from pandas.io.stata import StataReader
#      34 __all__ = [
#      35     "DataFrameGroupBy",
#      36     "DatetimeIndexResamplerGroupby",
#    (...)
#      54     "Window",
#      55 ]
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\__init__.py:1
# ----> 1 from pandas.io.json._json import (
#       2     read_json,
#       3     to_json,
#       4     ujson_dumps,
#       5     ujson_loads,
#       6 )
#       7 from pandas.io.json._table_schema import build_table_schema
#       9 __all__ = [
#      10     "ujson_dumps",
#      11     "ujson_loads",
#    (...)
#      14     "build_table_schema",
#      15 ]
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\_json.py:71
#      66 from pandas.io.json._normalize import convert_to_line_delimits
#      67 from pandas.io.json._table_schema import (
#      68     build_table_schema,
#      69     parse_table_schema,
#      70 )
# ---> 71 from pandas.io.parsers.readers import validate_integer
#      73 if TYPE_CHECKING:
#      74     from collections.abc import (
#      75         Hashable,
#      76         Mapping,
#      77     )
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\__init__.py:1
# ----> 1 from pandas.io.parsers.readers import (
#       2     TextFileReader,
#       3     TextParser,
#       4     read_csv,
#       5     read_fwf,
#       6     read_table,
#       7 )
#       9 __all__ = ["TextFileReader", "TextParser", "read_csv", "read_fwf", "read_table"]
#
# File c:\Users\princ\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\parsers\readers.py:32
#      29 from pandas._config import using_copy_on_write
#      31 from pandas._libs import lib
# ---> 32 from pandas._libs.parsers import STR_NA_VALUES
#      33 from pandas.errors import (
#      34     AbstractMethodError,
#      35     ParserWarning,
#      36 )
#      37 from pandas.util._decorators import Appender
#
# File parsers.pyx:1418, in init pandas._libs.parsers()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)

# %%
data = pd.read_csv("../files/Crop.csv")
data
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
data = data.drop(columns=['rainfall'])
# Out:
#         N   P   K  temperature   humidity        ph   label
# 0      90  42  43    20.879744  82.002744  6.502985    rice
# 1      85  58  41    21.770462  80.319644  7.038096    rice
# 2      60  55  44    23.004459  82.320763  7.840207    rice
# 3      74  35  40    26.491096  80.158363  6.980401    rice
# 4      78  42  42    20.130175  81.604873  7.628473    rice
# ...   ...  ..  ..          ...        ...       ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  coffee
#
# [2200 rows x 7 columns]

# %%
data["label"].unique().tolist()
# Out:
# ['rice',
#  'maize',
#  'chickpea',
#  'kidneybeans',
#  'pigeonpeas',
#  'mothbeans',
#  'mungbean',
#  'blackgram',
#  'lentil',
#  'pomegranate',
#  'banana',
#  'mango',
#  'grapes',
#  'watermelon',
#  'muskmelon',
#  'apple',
#  'orange',
#  'papaya',
#  'coconut',
#  'cotton',
#  'jute',
#  'coffee']

# %%
y = data["label"]

# %%
x = data.drop(columns=['label'])

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state=101)

# %%
rfclassifier = RandomForestClassifier()
rfclassifier.fit(X_train,y_train)
rf_pred = rfclassifier.predict(X_test)
rf_accuracy = accuracy_score(y_test,rf_pred)
print("Accuracy score:",rf_accuracy)
# Out:
# Accuracy score: 1.0

# %%
dtclassifier = DecisionTreeClassifier()
dtclassifier.fit(X_train,y_train)
dt_pred = dtclassifier.predict(X_test)
dt_accuracy = accuracy_score(y_test,dt_pred)
print("Accuracy score:",dt_accuracy)
# Out:
# Accuracy score: 1.0

# %%
from joblib import dump, load
dump(rfclassifier, '../files/CropRandomForest.joblib')
# Out:
# ['../files/CropRandomForest.joblib']
